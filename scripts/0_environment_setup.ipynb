# %% [markdown]
# # Installations
# Using PIP to install packages.
# Python versions were tested successfully from 3.8 to 3.12.

# %%
### Python Libraries ###
# !python -m pip install --upgrade pip

# Install core libraries
# !python -m pip install numpy
# !python -m pip install matplotlib
# !python -m pip install scipy
# !python -m pip install scikit-learn
# !python -m pip install seaborn
# !python -m pip install python-sensors

# Install file and path handling libraries
# !python -m pip install natsort

# Install GUI-related libraries
# !python -m pip install tkinter
# !python -m pip install open3d
# !python -m pip install open3d-python

# Install ANSYS-related libraries
# !python -m pip install pyaedt

# Install any additional libraries
# !python -m pip install pysensors
# !python -m pip install opencv-python

# %% [markdown]
# # Data download
# Input data are publicly available and script are pre-set to take these. Simply change the 'folder' variable at the head of each script to point to the __unzipped__ folder provided.

# %% [markdown]
# [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.16782866.svg)](https://doi.org/10.5281/zenodo.16782866)
#
# https://doi.org/10.5281/zenodo.16782866
